# %% [markdown]
# <a href="https://colab.research.google.com/github/jeronimoch49/LAB-Python-01/blob/main/ejercicio02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
edad = int(input("Ingrese su edad: "))

if edad >= 18:

    tiene_licencia = input("¿Tiene licencia? (s/n): ")

    if tiene_licencia == "s":
        sancion = input("Usted tiene alguna sancion? (s/n)? ")
        if sancion == "s":
            print("Usted puede conducir pero corre el riesgo de ser multado")

        else:
            print("Usted puede conducir sin problemas")
    else:
        print("Usted no puede conducir por no tener licencia")

else:
    print("Usted no puede conducir por ser menor de edad")
# Out:
# Ingrese su edad: 18
# ¿Tiene licencia? (s/n): s
# Usted tiene alguna sancion? (s/n)? n
# Usted puede conducir sin problemas

# %%
suma = 0
for i in range(1, 6):
    suma += i
print(f"La suma de N numeros naturales es {suma}")

for i in range(1, 6):
    if i % 2 == 0:
        print(i, end= " ")

print()

acumulador = 0
for i in range(1, 6):
    acumulador += 1
print(acumulador)

temperaturas = [22.5, 23.0, 21.8, 24.3, 25.1]
prom = sum(temperaturas) / len(temperaturas)

for i in temperaturas:
    if i > prom:
        print(i, end=" ")
# Out:
# La suma de N numeros naturales es 15
# 2 4
# 5
# 24.3 25.1

# %%
contador = 5
while contador >= 0:
    print("Contador:", contador)
    contador -= 1
# Out:
# Contador: 5
# Contador: 4
# Contador: 3
# Contador: 2
# Contador: 1
# Contador: 0

# %%
numero = int(input("Ingrese un numero: "))

while numero != 0:
    numero = int(input("Ingrese un numero: "))

# El estado del ciclo es la variable numero porque hasta que no ingrese 0 no se detendra
# Out:
# Ingrese un numero: 12
# Ingrese un numero: 15
# Ingrese un numero: 1
# Ingrese un numero: 2
# Ingrese un numero: 0

# %%
suma_pares = 0
suma_impares = 0
for i in range(1, 11):
    if i % 2 == 0:
        suma_pares += i
    else:
        suma_impares +=i

resultados = {
    "resultado pares": suma_pares,
    "resultado impares": suma_impares
}
print(resultados)

# El estado cambia ya que el ciclo al revisar uno por uno tiene que ir cambiando entre las variables suma_pares y sumas_impares porque los numeros pares e impares son intercalados
# Out:
# {'resultado pares': 30, 'resultado impares': 25}

# %%
productos = []
while True:
    nombre = input("Ingrese producto (o 'fin' para salir): ")
    if nombre == "fin":
        break
    precio = float(input("Precio: "))
    cantidad = int(input("Cantidad: "))
    productos.append({"nombre": nombre, "precio": precio, "cantidad": cantidad})

# Mostrar total
total = 0
for p in productos:
    if p["precio"] < 0 or p["cantidad"] < 0:
        continue
    total += p["precio"] * p["cantidad"]
    producto_mc = max(productos, key=lambda p: p["precio"])
print("Total del inventario:", total)
print(f"El producto más caro es: {producto_mc['nombre']} con un precio de {producto_mc['precio']}")

estado_f = [
    {"Total inventario": total},
    {"Producto mas caro": producto_mc}
]
print(estado_f)
# Out:
# Ingrese producto (o 'fin' para salir): arroz
# Precio: 5000
# Cantidad: 2
# Ingrese producto (o 'fin' para salir): sal
# Precio: 2500
# Cantidad: 1
# Ingrese producto (o 'fin' para salir): cereales
# Precio: 6000
# Cantidad: 6
# Ingrese producto (o 'fin' para salir): fin
# Total del inventario: 48500.0
# El producto más caro es: cereales con un precio de 6000.0
# [{'Total inventario': 48500.0}, {'Producto mas caro': {'nombre': 'cereales', 'precio': 6000.0, 'cantidad': 6}}]
